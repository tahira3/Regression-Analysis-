# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.metrics import r2_score

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
df = pd.read_csv('C:\\Users\\HP\\Downloads\\predictibility model - 2.csv')

# %%
df.head()
# Out:
#    Contact number (identifier )                                    Area  \
# 0                    1540047822  Betka Chowrasta, Tongibari, Munshiganj
# 1                    1919608550           Baluakandi Gazaria Munshiganj
# 2                    1732326700                      Barogonia gate1010
# 3                    1735051242                               Badarganj
# 4                    1918375514         Banatibazar,kalapara,patuakhali
#
#    Family member  Cooking frequency  Yearly occasions (disscount factor)  \
# 0              5                  4                                    9
# 1              2                  2                                   13
# 2              2                  2                                    8
# 3              3                  3                                    7
# 4              3                  3                                    9
#
#    Location factor (disscount factor)  Birthday ( discount factor )  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Contact number (identifier )         152 non-null    int64
#  1   Area                                 152 non-null    object
#  2   Family member                        152 non-null    int64
#  3   Cooking frequency                    152 non-null    int64
#  4   Yearly occasions (disscount factor)  152 non-null    int64
#  5   Location factor (disscount factor)   152 non-null    int64
#  6   Birthday ( discount factor )         152 non-null    int64
#  7   Eid occasion ( discount factor)      152 non-null    int64
#  8   Usage score                          152 non-null    int64
#  9   Grade                                152 non-null    object
#  10  Gas tank longivity( days)            152 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Contact number (identifier )  Family member  Cooking frequency  \
# count                  1.520000e+02     152.000000         152.000000
# mean                   1.746483e+09       4.230263           3.368421
# std                    1.462914e+08       1.434995           0.803009
# min                    1.303524e+09       2.000000           2.000000
# 25%                    1.709537e+09       3.000000           3.000000
# 50%                    1.728880e+09       4.000000           3.000000
# 75%                    1.846015e+09       5.000000           4.000000
# max                    1.978900e+09       9.000000           7.000000
#
#        Yearly occasions (disscount factor)  \
# count                           152.000000
# mean                             11.644737
# std                               2.635489
# min                               7.000000
# 25%                               9.000000
# 50%                              12.000000
# ...

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# <h4>Correlation Map</h4>

# %%
df.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8336\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                                   Contact number (identifier )  \
# Contact number (identifier )                                          1.000000
# family member         (Input factor)                                 -0.002372
# cooking frequency  (input factor)                                    -0.037229
# yearly occasions (disscount factor)                                  -0.025253
# Location factor ( discount factor)                                   -0.027746
# Birthday ( discount factor )                                         -0.002372
# Eid occasion ( discount factor)                                            NaN
# ...

# %%
ax1 = sns.heatmap(df.corr(), cbar=0,annot=True, cmap='crest')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8336\3419198418.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax1 = sns.heatmap(df.corr(), cbar=0,annot=True, cmap='crest')

# %%
width = 6
height = 4
plt.figure(figsize=(width, height))
sns.regplot(x="Family member", y="Gas tank longivity( days)", data=df)

# slope, intercept = np.polyfit(df["family member"], df["Gas tank longivity( days)"], 1)

# # # annotate the plot with the regression equation

# plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}", xy=(30, 5), xytext=(30, 5), fontsize=12, color="red", ha="left")

plt.ylim(0,)
# Out:
# (0.0, 41.86430708190043)

# %%
width = 6
height = 4
plt.figure(figsize=(width, height))
sns.regplot(x="Cooking frequency", y="Gas tank longivity( days)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 42.36749696153675)

# %%
width = 6
height = 4
plt.figure(figsize=(width, height))
sns.regplot(x="Yearly occasions (disscount factor)", y="Gas tank longivity( days)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 41.4)

# %%
width = 6
height = 4
plt.figure(figsize=(width, height))
sns.regplot(x="Birthday ( discount factor )", y="Gas tank longivity( days)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 41.86868111362911)

# %%
width = 6
height = 4
plt.figure(figsize=(width, height))
sns.regplot(x="Usage score", y="Gas tank longivity( days)", data=df)
plt.ylim(0,)
# Out:
# (0.0, 42.33018655537366)

# %% [markdown]
# <h4>Multiple Linear Regression</h4>

# %%
Z = df[['Family member', 'Cooking frequency', 'Usage score', 'Yearly occasions (disscount factor)','Birthday ( discount factor )']]
lm.fit(Z, df['Gas tank longivity( days)'])
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# 65.50549317938729

# %%
lm.coef_
# Out:
# array([-3.31497872, -9.05444947,  1.1476082 , -1.0884166 , -3.31497872])

# %% [markdown]
# <h4>R-square value for multiple linear regression</h4>

# %%
print('The R-square value is: ', lm.score(Z, df['Gas tank longivity( days)']))
# Out:
# The R-square value is:  0.9731258305097069

# %% [markdown]
# we have got r-square value of 0.97 that indicates that our model is 97% accurate and we can use the model to predict gas tank longitivity with respect to the variable family member,cooking frequency,usage score,birthday and yearly occasions.<br></br>
# Here's our model,<br></br>   Y=65.5+(-3.31*a)+(-9.05*b)+(1.14*c)+(-1.08*d)+(-3.31*e)<br></br>
# a=Family member<br></br>
# b=Cooking frequency<br></br>
# c=Usage score<br></br>
# d=Yearly occasions (disscount factor)<br></br>
# e=Birthday ( discount factor )

# %%
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['Gas tank longivity( days)'], hist=False, color="g", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Predicted Values" , ax=ax1)



plt.title('Actual vs Predicted Values for Gas tank longivity( days)')
# plt.xlabel('Factors')
# plt.ylabel('Gas tank longivity( days)')
plt.legend()

plt.show()
plt.close()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8336\3062542445.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df['Gas tank longivity( days)'], hist=False, color="g", label="Actual Value")
# C:\Users\HP\AppData\Local\Temp\ipykernel_8336\3062542445.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
print(Y_hat)
# Out:
# [19.62279645 39.49660295 39.20064495 29.19508742 29.31347062 29.60942862
#  26.30391258 26.18552938 20.03713765 19.97794605 19.74117965 19.97794605
#  19.97794605 15.89889675 15.72132195 15.89889675 15.78051355 17.997613
#  13.99382114 15.5827288  14.28977914 14.23058754 13.93462954 17.7608466
#  17.997613   17.7608466  17.7608466  17.8792298  19.85956285 17.8792298
#  19.74117965 19.85956285 20.03713765 19.74117965 18.0568046  19.91875445
#  17.7608466  19.62279645 19.80037125 19.80037125 19.74117965 19.62279645
#  20.03713765 17.9384214  19.68198805 19.74117965 19.80037125 19.85956285
#  18.0568046  17.7608466  17.6424634  18.0568046  19.74117965 19.74117965
#  20.03713765 17.997613   17.9384214  17.8792298  19.85956285 17.7608466
#  19.62279645 19.97794605 19.62279645 19.74117965 19.97794605 29.60942862
#  26.24472098 26.18552938 26.12633778 29.55023702 29.37266222 26.18552938
#  29.49104542 29.49104542 26.12633778 26.42229578 26.06714618 29.55023702
# ...
